# %% [markdown]
# <a href="https://colab.research.google.com/github/tilin1841j/localidades_kennedy/blob/main/barrios_de_kennedy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gdp

# %%
gdf_barrios = gdp.read_file('barrios.c.geojson')
gdf_barrios
# Out:
#       fid SCACODIGO  SCATIPO             SCANOMBRE  SHAPE_Leng  SHAPE_Area  \
# 0       6    004555        0       PATIO BONITO II    0.021316    0.000020
# 1       7    004581        0              TIMIZA C    0.019610    0.000017
# 2      10    004609        0         LOS ALMENDROS    0.016461    0.000014
# 3      17    004618        0             DINTALITO    0.021894    0.000020
# 4      34    004601        0            CALANDAIMA    0.021104    0.000026
# ..    ...       ...      ...                   ...         ...         ...
# 102  1155    004576        0       CASA BLANCA SUR    0.023590    0.000022
# 103  1176    004541        0       EL PARAISO BOSA    0.017645    0.000007
# 104  1181    105342        1   SABANA GRANDE RURAL    0.016197    0.000003
# 105  1182    105211        1      OSORIO XII RURAL    0.012021    0.000005
# 106  1190    004502        0  HIPOTECHO OCCIDENTAL    0.035643    0.000070
#
#     LocNombre                                           geometry
# ...

# %%
gdf_barrios.plot()
# Out:
# <Axes: >

# %%
mapa_2= gdf_barrios.plot(
    column= "SCANOMBRE",
    figsize=(50,50),
    edgecolor='black',
    cmap= 'tab20',
    legend= True,
    legend_kwds ={
        'loc':'upper left'
    }
)
